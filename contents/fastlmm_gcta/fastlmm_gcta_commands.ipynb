# %% [markdown]
# # FASTLMM

# %%
ls -l

plink --bfile ./data/quantfamdata --assoc --out plinkresults
# Out:
# total 12289
# -rwxrwxrwx 1 ubuntu ubuntu     7222 Jun 22 22:45 FASTLMM_GCTA_commands.txt
# -rwxrwxrwx 1 ubuntu ubuntu     1089 Jun 22 22:45 LICENSE
# lrwxrwxrwx 1 ubuntu ubuntu       35 Sep  6 04:16 data -> /home/ubuntu/raw_data/fastlmm_gcta/
# -rwxrwxrwx 1 ubuntu ubuntu    14887 Sep  6 04:57 fastlmm_gcta_commands.ipynb
# -rwxrwxrwx 1 ubuntu ubuntu      853 Sep  6 06:56 plinkresults.log
# -rwxrwxrwx 1 ubuntu ubuntu 12550638 Sep  6 06:56 plinkresults.qassoc
# -rwxrwxrwx 1 ubuntu ubuntu     7019 Jun 22 22:45 qqmanHJCupdated.R
# PLINK v1.9.0-b.8 64-bit (22 Oct 2024)              cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plinkresults.log.
# Options in effect:
#   --assoc
#   --bfile ./data/quantfamdata
#   --out plinkresults
#
# 15485 MB RAM detected; reserving 7742 MB for main workspace.
# 134946 variants loaded from .bim file.
# 498 people (226 males, 272 females) loaded from .fam.
# ...

# %%
res1 <- read.table("plinkresults.qassoc", header = T)
head(res1)
source("qqmanHJCupdated.R")

png("mh1.png")
manhattan(res1,
    pch = 20, suggestiveline = F, genomewideline = F, ymin = 2,
    cex.x.axis = 0.65, colors = c("black", "dodgerblue"), cex = 0.5
)
dev.off()

png("qq1.png")
qq(res1$P)
dev.off()

chi <- (qchisq(1 - res1$P, 1))
lambda <- median(chi) / 0.456
lambda
# Out:
#   CHR SNP        BP      NMISS BETA      SE     R2        T        P
# 1 1   rs9326624   558615 498    0.526900 0.9159 6.668e-04  0.57530 0.5654
# 2 1   rs3094315   742429 498    0.306700 0.5377 6.555e-04  0.57040 0.5687
# 3 1   rs12562034  758311 495    0.793000 0.8845 1.628e-03  0.89650 0.3704
# 4 1   rs3934834   995669 498   -0.007573 0.6342 2.875e-07 -0.01194 0.9905
# 5 1   rs3737728  1011278 498    0.465700 0.6392 1.069e-03  0.72860 0.4666
# 6 1   rs4970405  1038818 498   -0.829400 0.7574 2.412e-03 -1.09500 0.2740
# agg_record_712834015
#                    2
# agg_record_712834015
#                    2
# [1] 1.102493

# %%
fastlmmc -bfile ./data/quantfamdata -pheno ./data/quantfamdata.fam -mpheno 4 -bfileSim ./data/quantfamdata -ML -out FLMMresults
# Out:
# FastLmmC v2.07.20240410 - Factored Spectrally Transformed Linear Mixed Models [Release]
#   Copyright Microsoft Corporation -- Licensed Only for Non-Commercial use.
#   Compiled Apr 10 2024 at 22:40:56 by 129dcc04da00 for Linux v3.x kernel
#   using 0
#
#  ++    Start Processing CommandLine:
#  --      End Processing CommandLine:
#
#  ++      Start Loading FastLmm Data:
#   ++  Start Loading Covariance Data:
#    ++      Processing PLINK fileset: [./data/quantfamdata]
#    ReadBinaryFiles4()* elapsed time: 861.857 ms
#      Number of Individuals Selected:     498
#                Number of Phenotypes:       1
#                 Number of SNPs Read:  134946
#                 Number of SNPs Used:  134946
#    --  End Processing PLINK fileset: [./data/quantfamdata]
#   --    End Loading Covariance Data:
#   ++        Start Loading Test Data:
#    ++      Processing PLINK fileset: [./data/quantfamdata]
#    ReadBinaryFiles4()* elapsed time: 742.346 ms
# ...

# %%
res2 <- read.table("FLMMresults", header = T)
head(res2)

chi <- (qchisq(1 - res2$Pvalue, 1))
lambda <- median(chi) / 0.456
lambda

new <- data.frame(res2$SNP, res2$Chromosome, res2$Position, res2$Pvalue)
names(new) <- c("SNP", "CHR", "BP", "P")
head(new)

png("qq2.png")
qq(new$P)
dev.off()

png("mh2.png")
manhattan(new,
    pch = 20, suggestiveline = F, genomewideline = F, ymin = 2,
    cex.x.axis = 0.65, colors = c("black", "dodgerblue"), cex = 0.5
)
dev.off()
# Out:
#   SNP        Chromosome GeneticDistance Position  Pvalue       Qvalue       N
# 1 rs9271209   6         0                32687013 1.259515e-24 4.323843e-20 498
# 2 rs9271252   6         0                32688266 1.259515e-24 4.323843e-20 498
# 3 rs9271255   6         0                32688335 1.259515e-24 4.323843e-20 498
# 4 rs28366284  6         0                32668305 1.281651e-24 4.323843e-20 498
# 5 rs233722   12         0               111515857 3.800076e-22 1.025610e-17 498
# 6 rs233716   12         0               111524326 1.682225e-12 3.783491e-08 498
#   NullLogLike AltLogLike SNPWeight SNPWeightSE OddsRatio WaldStat  NullLogDelta
# 1 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 2 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 3 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 4 -1728.182   -1675.730  3.502775  0.3212447   671.93014 118.89199 -0.01280211
# ...

# %% [markdown]
# # GCTA

# %%
fam <- read.table("./data/quantfamdata.fam", header = F)
pheno <- data.frame(fam[, 1:2], fam[, 6])
write.table(pheno, file = "phenos.txt", col.names = F, row.names = F, quote = F)

# %%
gcta64 --mlma --bfile ./data/quantfamdata --pheno ./data/myphenos.txt --out GCTAresults
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 07:02:16 UTC on Sat Sep 06 2025.
# Hostname: Rui_Dong
#
# Accepted options:
# --mlma
# --bfile ./data/quantfamdata
# --pheno ./data/myphenos.txt
# --out GCTAresults
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading PLINK FAM file from [./data/quantfamdata.fam].
# 498 individuals to be included from [./data/quantfamdata.fam].
# Reading PLINK BIM file from [./data/quantfamdata.bim].
# 134946 SNPs to be included from [./data/quantfamdata.bim].
# ...

# %%
source("qqmanHJCupdated.R")

# %%
res3 <- read.table("GCTAresults.mlma", header = T)
head(res3)
# Out:
#   Chr SNP        bp      A1 A2 Freq      b         se       p
# 1 1   rs9326624   558615 G  A  0.0913655  0.693811 0.924665 0.453052
# 2 1   rs3094315   742429 G  A  0.3162650  0.494021 0.550792 0.369758
# 3 1   rs12562034  758311 A  G  0.0818182  0.827582 0.882891 0.348576
# 4 1   rs3934834   995669 A  G  0.1817270 -0.121518 0.640661 0.849563
# 5 1   rs3737728  1011278 A  G  0.1957830  0.513895 0.644486 0.425236
# 6 1   rs4970405  1038818 G  A  0.1194780 -0.697621 0.764350 0.361401

# %%
chi <- (qchisq(1 - res3$p, 1))
lambda <- median(chi) / 0.456
lambda
# Out:
# [1] 0.9869874

# %%
new3 <- data.frame(res3$SNP, res3$Chr, res3$bp, res3$p)
names(new3) <- c("SNP", "CHR", "BP", "P")
head(new3)
# Out:
#   SNP        CHR BP      P
# 1 rs9326624  1    558615 0.453052
# 2 rs3094315  1    742429 0.369758
# 3 rs12562034 1    758311 0.348576
# 4 rs3934834  1    995669 0.849563
# 5 rs3737728  1   1011278 0.425236
# 6 rs4970405  1   1038818 0.361401

# %%
png("qq3.png")
qq(new3$P)
dev.off()

png("mh3.png")
manhattan(new3,
    pch = 20, suggestiveline = F, genomewideline = F, ymin = 2,
    cex.x.axis = 0.65, colors = c("black", "dodgerblue"), cex = 0.5
)
dev.off()

res2 <- read.table("FLMMresults", header = T)
new2 <- data.frame(res2$SNP, res2$Chromosome, res2$Position, res2$Pvalue)
names(new2) <- c("SNP", "CHR", "BP", "P")
merged <- merge(new3, new2, by = "SNP", sort = F)
# Out:
# agg_record_973325991
#                    2
# agg_record_973325991
#                    2

# %%
head(res2)
head(new2)
head(new3)
head(merged)
# Out:
#   SNP        Chromosome GeneticDistance Position  Pvalue       Qvalue       N
# 1 rs9271209   6         0                32687013 1.259515e-24 4.323843e-20 498
# 2 rs9271252   6         0                32688266 1.259515e-24 4.323843e-20 498
# 3 rs9271255   6         0                32688335 1.259515e-24 4.323843e-20 498
# 4 rs28366284  6         0                32668305 1.281651e-24 4.323843e-20 498
# 5 rs233722   12         0               111515857 3.800076e-22 1.025610e-17 498
# 6 rs233716   12         0               111524326 1.682225e-12 3.783491e-08 498
#   NullLogLike AltLogLike SNPWeight SNPWeightSE OddsRatio WaldStat  NullLogDelta
# 1 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 2 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 3 -1728.182   -1675.713  3.497918  0.3213077   573.51257 118.51599 -0.01280211
# 4 -1728.182   -1675.730  3.502775  0.3212447   671.93014 118.89199 -0.01280211
# ...

# %%
png("compareGCTAFLMM.png")
plot(-log10(merged$P.x), -log10(merged$P.y))
abline(0, 1)
dev.off()
# Out:
# agg_record_50408535
#                   2

# %%
gcta64 --bfile ./data/quantfamdata --autosome --make-grm-bin --out GCTAgrm 

gcta64 --reml --grm-bin GCTAgrm --pheno ./data/myphenos.txt --out GCTAherit 

gcta64 --bfile ./data/quantfamdata --chr 1 --make-grm-bin --out GCTAgrmchr1 
gcta64 --reml --grm-bin GCTAgrmchr1 --pheno ./data/myphenos.txt \
--out GCTAheritchr1

gcta64 --bfile ./data/quantfamdata --chr 2 --make-grm-bin --out GCTAgrmchr2
gcta64 --reml --grm-bin GCTAgrmchr2 --pheno ./data/myphenos.txt \
--out GCTAheritchr2 

gcta64 --bfile ./data/quantfamdata --chr 6 --make-grm-bin --out GCTAgrmchr6 
gcta64 --reml --grm-bin GCTAgrmchr6 --pheno ./data/myphenos.txt --out GCTAheritchr6


gcta64 --bfile ./data/quantfamdata --chr 12 --make-grm-bin --out GCTAgrmchr12
gcta64 --reml --grm-bin GCTAgrmchr12 --pheno ./data/myphenos.txt --out GCTAheritchr12


gcta64 --bfile ./data/quantfamdata --chr 3 --make-grm-bin --out GCTAgrmchr3
gcta64 --bfile ./data/quantfamdata --chr 4 --make-grm-bin --out GCTAgrmchr4
gcta64 --bfile ./data/quantfamdata --chr 5 --make-grm-bin --out GCTAgrmchr5
gcta64 --bfile ./data/quantfamdata --chr 7 --make-grm-bin --out GCTAgrmchr7
gcta64 --bfile ./data/quantfamdata --chr 8 --make-grm-bin --out GCTAgrmchr8
gcta64 --bfile ./data/quantfamdata --chr 9 --make-grm-bin --out GCTAgrmchr9
gcta64 --bfile ./data/quantfamdata --chr 10 --make-grm-bin --out GCTAgrmchr10
gcta64 --bfile ./data/quantfamdata --chr 11 --make-grm-bin --out GCTAgrmchr11
gcta64 --bfile ./data/quantfamdata --chr 13 --make-grm-bin --out GCTAgrmchr13
gcta64 --bfile ./data/quantfamdata --chr 14 --make-grm-bin --out GCTAgrmchr14
gcta64 --bfile ./data/quantfamdata --chr 15 --make-grm-bin --out GCTAgrmchr15
gcta64 --bfile ./data/quantfamdata --chr 16 --make-grm-bin --out GCTAgrmchr16
gcta64 --bfile ./data/quantfamdata --chr 17 --make-grm-bin --out GCTAgrmchr17
gcta64 --bfile ./data/quantfamdata --chr 18 --make-grm-bin --out GCTAgrmchr18
gcta64 --bfile ./data/quantfamdata --chr 19 --make-grm-bin --out GCTAgrmchr19
gcta64 --bfile ./data/quantfamdata --chr 20 --make-grm-bin --out GCTAgrmchr20
gcta64 --bfile ./data/quantfamdata --chr 21 --make-grm-bin --out GCTAgrmchr21
gcta64 --bfile ./data/quantfamdata --chr 22 --make-grm-bin --out GCTAgrmchr22 

gcta64 --reml --mgrm-bin ./data/multipleGRMs.txt --pheno ./data/myphenos.txt --out GCTAherit22GRMs 

gcta64 --mgrm-bin ./data/multipleGRMsnot6.txt --make-grm --out GCTAgrmnot6 

gcta64 --reml --mgrm-bin ./data/multipleGRMs6andnot6.txt --pheno ./data/myphenos.txt \
--out GCTAherit6andnot6 


gcta64 --grm GCTAgrm --make-bK-sparse 0.05 --out GCTAsparsegrm 

gcta64 --bfile ./data/quantfamdata --make-grm-part 3 1 --thread-num 5 \
--out test
gcta64 --bfile ./data/quantfamdata --make-grm-part 3 2 --thread-num 5 \
--out test
gcta64 --bfile ./data/quantfamdata --make-grm-part 3 3 --thread-num 5 \
--out test
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 07:11:15 UTC on Sat Sep 06 2025.
# Hostname: Rui_Dong
#
# Accepted options:
# --bfile ./data/quantfamdata
# --autosome
# --make-grm-bin
# --out GCTAgrm
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading PLINK FAM file from [./data/quantfamdata.fam].
# 498 individuals to be included from [./data/quantfamdata.fam].
# Reading PLINK BIM file from [./data/quantfamdata.bim].
# 134946 SNPs to be included from [./data/quantfamdata.bim].
# ...

# %%
cat test.part_3_*.grm.id > test.grm.id
cat test.part_3_*.grm.bin > test.grm.bin
cat test.part_3_*.grm.N.bin > test.grm.N.bin

# %%
gcta64 --grm test --make-bK-sparse 0.05 --out newsparsegrm 

head *.sp
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 07:13:45 UTC on Sat Sep 06 2025.
# Hostname: Rui_Dong
#
# Options:
#
# --grm test
# --make-bK-sparse 0.05
# --out newsparsegrm
#
# Pruning the GRM to a sparse matrix with a cutoff of 0.050000...
# Total number of parts to be processed: 1
#     Saving 498 individual IDs
#     Processing part 1
# Saving the sparse GRM (894 pairs) to [newsparsegrm.grm.sp]
# finished generating a sparse GRM Success:
#
# Analysis finished at 07:13:45 UTC on Sat Sep 06 2025
# Overall computational time: 0.53 sec.
# ==> GCTAsparsegrm.grm.sp <==
# 0	0	0.98112994
# 1	0	0.10253313
# 1	1	0.99352777
# 2	2	1.0000606
# ...

# %%
gcta64 --grm-bin GCTAgrm --pca 5 --out pcs 

gcta64 --bfile ./data/quantfamdata --grm-sparse GCTAsparsegrm \
--fastGWA-mlm --pheno ./data/myphenos.txt --qcovar pcs.eigenvec \
--out sparse_assoc 

gcta64 --bfile ./data/quantfamdata --grm-sparse newsparsegrm \
--fastGWA-mlm --pheno ./data/myphenos.txt --qcovar pcs.eigenvec \
--out newsparse_assoc 

gcta64 --bfile ./data/quantfamdata --grm-sparse GCTAsparsegrm \
--fastGWA-mlm --pheno ./data/myphenos.txt --out LMMsparse_assoc 

gcta64 --bfile ./data/quantfamdata --grm-sparse newsparsegrm \
--fastGWA-mlm --pheno ./data/myphenos.txt --out LMMnewsparse_assoc
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version v1.94.1 Linux
# * Built at Nov 15 2022 21:14:25, by GCC 8.5
# * (C) 2010-present, Yang Lab, Westlake University
# * Please report bugs to Jian Yang <jian.yang@westlake.edu.cn>
# *******************************************************************
# Analysis started at 07:14:35 UTC on Sat Sep 06 2025.
# Hostname: Rui_Dong
#
# Accepted options:
# --grm-bin GCTAgrm
# --pca 5
# --out pcs
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading IDs of the GRM from [GCTAgrm.grm.id].
# 498 IDs are read from [GCTAgrm.grm.id].
# Reading the GRM from [GCTAgrm.grm.bin].
# GRM for 498 individuals are included from [GCTAgrm.grm.bin].
#
# Performing principal component analysis ...
# ...

# %%
res4 <- read.table("sparse_assoc.fastGWA", header = T)
res5 <- read.table("newsparse_assoc.fastGWA", header = T)
res6 <- read.table("LMMsparse_assoc.fastGWA", header = T)
res7 <- read.table("LMMnewsparse_assoc.fastGWA", header = T)

head(res4)
head(res5)
head(res6)
head(res7)
# Out:
#   CHR SNP        POS     A1 A2 N   AF1       BETA      SE       P
# 1 1   rs9326624   558615 G  A  498 0.0913655  0.590323 0.905413 0.514406
# 2 1   rs3094315   742429 G  A  498 0.3162650  0.490010 0.531356 0.356430
# 3 1   rs12562034  758311 A  G  495 0.0818182  0.722313 0.874147 0.408630
# 4 1   rs3934834   995669 A  G  498 0.1817270  0.168088 0.626957 0.788621
# 5 1   rs3737728  1011278 A  G  498 0.1957830  0.376003 0.632034 0.551904
# 6 1   rs4970405  1038818 G  A  498 0.1194780 -0.737277 0.748977 0.324930
#   CHR SNP        POS     A1 A2 N   AF1       BETA      SE       P
# 1 1   rs9326624   558615 G  A  498 0.0913655  0.590323 0.905413 0.514406
# 2 1   rs3094315   742429 G  A  498 0.3162650  0.490010 0.531356 0.356430
# 3 1   rs12562034  758311 A  G  495 0.0818182  0.722313 0.874147 0.408630
# 4 1   rs3934834   995669 A  G  498 0.1817270  0.168088 0.626957 0.788621
# 5 1   rs3737728  1011278 A  G  498 0.1957830  0.376003 0.632034 0.551904
# ...

# %%
chi <- (qchisq(1 - res4$P, 1))
lambda <- median(chi) / 0.456
lambda
chi <- (qchisq(1 - res5$P, 1))
lambda <- median(chi) / 0.456
lambda
chi <- (qchisq(1 - res6$P, 1))
lambda <- median(chi) / 0.456
lambda
chi <- (qchisq(1 - res7$P, 1))
lambda <- median(chi) / 0.456
lambda
# Out:
# [1] 1.061026
# [1] 1.061026
# [1] 1.004384
# [1] 1.004384

# %%
source("qqmanHJCupdated.R") 

new4<-data.frame(res4$SNP, res4$CHR, res4$POS, res4$P)
names(new4)<-c("SNP", "CHR", "BP", "P") 

png("qq4.png")
qq(new4$P)
dev.off() 

png("mh4.png")
manhattan(new4, pch=20, suggestiveline=F, genomewideline=F, ymin=2,
cex.x.axis=0.65, colors=c("black","dodgerblue"), cex=0.5)
dev.off() 

new5<-data.frame(res5$SNP, res5$CHR, res5$POS, res5$P)
names(new5)<-c("SNP", "CHR", "BP", "P") 

png("qq5.png")
qq(new5$P)
dev.off() 

png("mh5.png")
manhattan(new5, pch=20, suggestiveline=F, genomewideline=F, ymin=2,
cex.x.axis=0.65, colors=c("black","dodgerblue"), cex=0.5)
dev.off() 

new6<-data.frame(res6$SNP, res6$CHR, res6$POS, res6$P)
names(new6)<-c("SNP", "CHR", "BP", "P")

png("qq6.png")
qq(new6$P)
dev.off() 

png("mh6.png")
manhattan(new6, pch=20, suggestiveline=F, genomewideline=F, ymin=2,
cex.x.axis=0.65, colors=c("black","dodgerblue"), cex=0.5)
dev.off() 

new7<-data.frame(res7$SNP, res7$CHR, res7$POS, res7$P)
names(new7)<-c("SNP", "CHR", "BP", "P")

png("qq7.png")
qq(new7$P)
dev.off() 

png("mh7.png")
manhattan(new7, pch=20, suggestiveline=F, genomewideline=F, ymin=2,
cex.x.axis=0.65, colors=c("black","dodgerblue"), cex=0.5)
dev.off()

res3<-read.table("GCTAresults.mlma", header=T)
res7<-read.table("LMMnewsparse_assoc.fastGWA", header=T)
head(res3)
head(res7) 

png("compareGCTAfastGWA.png")
plot(-log10(res3$p),-log10(res7$P))
abline(0,1)
dev.off()
# Out:
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
# agg_record_99697622
#                   2
#   Chr SNP        bp      A1 A2 Freq      b         se       p
# 1 1   rs9326624   558615 G  A  0.0913655  0.693811 0.924665 0.453052
# 2 1   rs3094315   742429 G  A  0.3162650  0.494021 0.550792 0.369758
# 3 1   rs12562034  758311 A  G  0.0818182  0.827582 0.882891 0.348576
# 4 1   rs3934834   995669 A  G  0.1817270 -0.121518 0.640661 0.849563
# 5 1   rs3737728  1011278 A  G  0.1957830  0.513895 0.644486 0.425236
# 6 1   rs4970405  1038818 G  A  0.1194780 -0.697621 0.764350 0.361401
#   CHR SNP        POS     A1 A2 N   AF1       BETA       SE       P
# 1 1   rs9326624   558615 G  A  498 0.0913655  0.6800840 0.932956 0.466028
# ...
