# %%
plink --ped simcasecon.ped --map simcasecon.map --assoc
# Out:
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --assoc
#   --map simcasecon.map
#   --ped simcasecon.ped
#
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: plink-temporary.bed + plink-temporary.bim + plink-temporary.fam546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# Writing C/C --assoc report to plink.assoc ... done.

# %%
head plink.assoc
# Out:
#  CHR     SNP         BP   A1      F_A      F_U   A2        CHISQ            P           OR
#    0    snp1    1000000    2   0.4958   0.5022    1        0.338        0.561       0.9743
#    0    snp2    2000000    1   0.4942   0.4998    2        0.242       0.6228       0.9782
#    0    snp3    3000000    2   0.4212    0.408    1        1.447       0.2291        1.056
#    0    snp4    4000000    2   0.4105   0.4092    1      0.01292       0.9095        1.005
#    0    snp5    5000000    2   0.4205   0.3988    1        3.912      0.04793        1.094
#    0    snp6    6000000    2    0.388    0.358    1        7.697     0.005533        1.137
#    0    snp7    7000000    2   0.3842   0.3588    1         5.57      0.01827        1.115
#    0    snp8    8000000    2    0.377   0.3808    1       0.1195       0.7296       0.9842
#    0    snp9    9000000    2   0.3642   0.3718    1       0.4837       0.4867       0.9683

# %%
plink --ped simcasecon.ped --map simcasecon.map --model
 
head -1 plink.model 

grep GENO plink.model

plink --ped simcasecon.ped --map simcasecon.map --fast-epistasis 

plink --ped simcasecon.ped --map simcasecon.map --fast-epistasis --case-only 

plink --ped simcasecon.ped --map simcasecon.map --epistasis 

plink --ped simcasecon.ped --map simcasecon.map --make-bed --out simbinary
# Out:
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --map simcasecon.map
#   --model
#   --ped simcasecon.ped
#
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: plink-temporary.bed + plink-temporary.bim + plink-temporary.fam546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# Writing --model report to plink.model ... done.
#  CHR     SNP   A1   A2     TEST            AFF          UNAFF        CHISQ   DF            P
#    0    snp1    2    1     GENO   489/1005/506    519/971/510        1.494    2       0.4739
#    0    snp2    1    2     GENO    504/969/527    509/981/510       0.3772    2       0.8281
#    0    snp3    2    1     GENO    384/917/699    328/976/696         6.25    2      0.04394
#    0    snp4    2    1     GENO    355/932/713    345/947/708       0.2802    2       0.8693
#    0    snp5    2    1     GENO    387/908/705    311/973/716        10.61    2     0.004976
#    0    snp6    2    1     GENO    529/494/977   485/462/1053        5.826    2      0.05432
#    0    snp7    2    1     GENO    513/511/976   482/471/1047        5.087    2      0.07859
#    0    snp8    2    1     GENO    504/500/996    513/497/990       0.1068    2        0.948
#    0    snp9    2    1     GENO   475/507/1018   491/505/1004       0.3659    2       0.8328
#    0   snp10    2    1     GENO    501/520/979    500/510/990       0.1595    2       0.9233
#    0   snp11    2    1     GENO   502/490/1008    487/518/995         1.09    2       0.5799
#    0   snp12    2    1     GENO    512/496/992   505/476/1019       0.8222    2       0.6629
#    0   snp13    2    1     GENO    496/524/980    533/478/989        3.483    2       0.1752
#    0   snp14    2    1     GENO   475/499/1026    490/511/999       0.7357    2       0.6922
#    0   snp15    2    1     GENO   501/488/1011    517/493/990       0.4973    2       0.7798
#    0   snp16    2    1     GENO   485/489/1026    514/512/974        2.722    2       0.2564
#    0   snp91    2    1     GENO   334/619/1047   335/632/1033       0.2308    2        0.891
#    0   snp92    2    1     GENO   303/616/1081   329/642/1029        2.888    2       0.2359
#    0   snp93    2    1     GENO   346/633/1021   328/621/1051         1.03    2       0.5975
#    0   snp94    2    1     GENO   303/629/1068   315/633/1052       0.3664    2       0.8326
#    0   snp95    2    1     GENO   303/621/1076   335/635/1030        2.766    2       0.2508
#    0   snp96    2    1     GENO    352/663/985   317/651/1032        3.036    2       0.2192
#    0   snp97    2    1     GENO   294/650/1056   320/635/1045        1.334    2       0.5133
#    0   snp98    2    1     GENO   308/648/1044   306/589/1105        4.552    2       0.1027
#    0   snp99    2    1     GENO   310/655/1035   329/635/1036       0.8755    2       0.6455
#    0  snp100    2    1     GENO   317/662/1021    330/674/996       0.6789    2       0.7122
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --fast-epistasis
#   --map simcasecon.map
#   --ped simcasecon.ped
#
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: plink-temporary.bed + plink-temporary.bim + plink-temporary.fam546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using up to 4 threads (change this with --threads).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# --fast-epistasis to plink.epi.cc ... 0% [processingwriting]          done.
# 4950 valid tests performed, summary written to plink.epi.cc.summary .
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --case-only
#   --fast-epistasis
#   --map simcasecon.map
#   --ped simcasecon.ped
#
# Note: --case-only flag deprecated.  Use "--fast-epistasis case-only".
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: plink-temporary.bed + plink-temporary.bim + plink-temporary.fam546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using up to 4 threads (change this with --threads).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# --fast-epistasis case-only to plink.epi.co ... 0% [processingwriting]          done.
# 4950 valid tests performed, summary written to plink.epi.co.summary .
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --epistasis
#   --map simcasecon.map
#   --ped simcasecon.ped
#
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: plink-temporary.bed + plink-temporary.bim + plink-temporary.fam546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using up to 4 threads (change this with --threads).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# C/C --epistasis to plink.epi.cc ... 0% [processingwriting]          done.
# 4950 valid tests performed, summary written to plink.epi.cc.summary .
# PLINK v1.90b6.21 64-bit (19 Oct 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to simbinary.log.
# Options in effect:
#   --make-bed
#   --map simcasecon.map
#   --out simbinary
#   --ped simcasecon.ped
#
# 31376 MB RAM detected; reserving 15688 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (100 variants, 4000 people).
# --file: simbinary-temporary.bed + simbinary-temporary.bim +940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%
# simbinary-temporary.fam written.
# 100 variants loaded from .bim file.
# 4000 people (2008 males, 1992 females) loaded from .fam.
# 4000 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 4000 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 100 variants and 4000 people pass filters and QC.
# Among remaining phenotypes, 2000 are cases and 2000 are controls.
# --make-bed to simbinary.bed + simbinary.bim + simbinary.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
cassi -lr -i simbinary.bed
# Out:
# CASSI: SNP interaction analysis software, v2.51
# -----------------------------------------------
# Copyright 2012-2017 Richard Howey, GNU General Public License, v3
# Institute of Genetic Medicine, Newcastle University
#
# Parameters:
# Input file: simbinary.bed
# Output file: cassi.out
# Log file: cassi.log
# Start SNP of first SNP window: 1
# End SNP of first window is the last SNP
# Start SNP of second SNP window: 1
# End SNP of second window is the last SNP
# Memory: SNPs stored in binary format
# Maximum no. of results: 1000000
#
# Data Summary Statistics:
# Number of SNPs: 100
# Number of subjects: 4000
# Number of cases: 2000 (50%)
# Number of controls: 2000 (50%)
# Number of missing: 0
#
# Test Statistic: Logistic Regression
# P-value threshold for case/control results: 0.0001
# Total SNP pairs calculated: 4950
# Total SNP pair statistics passing threshold: 2
#
# Number of SNP pairs with results: 2
#
# Run time: less than one second

# %%
results<-read.table("cassi.out", header=T)
results
# Out:
#   SNP1 CHR1 ID1   BP1      SNP2 CHR2 ID2   BP2      LR_LOG_OR LR_SE
# 1  1   0    snp1   1000000  2   0    snp2   2000000  1.083560 0.0604050
# 2 15   0    snp15 15000000 77   0    snp77 77000000 -0.214053 0.0510153
#   LR_CHISQ LR_P
# 1 321.7790 5.93600e-72
# 2  17.6052 2.71838e-05

# %%
cassi -je -o cassiJE.out -i simbinary.bed
# Out:
# CASSI: SNP interaction analysis software, v2.51
# -----------------------------------------------
# Copyright 2012-2017 Richard Howey, GNU General Public License, v3
# Institute of Genetic Medicine, Newcastle University
#
# Parameters:
# Input file: simbinary.bed
# Output file: cassiJE.out
# Log file: cassiJE.log
# Start SNP of first SNP window: 1
# End SNP of first window is the last SNP
# Start SNP of second SNP window: 1
# End SNP of second window is the last SNP
# Case only base pair gap: 1000
# Memory: SNPs stored in binary format
# Maximum no. of results: 1000000
#
# Data Summary Statistics:
# Number of SNPs: 100
# Number of subjects: 4000
# Number of cases: 2000 (50%)
# Number of controls: 2000 (50%)
# Number of missing: 0
#
# Test Statistic: Joint Effects
# P-value threshold for case/control results: 0.0001
# P-value threshold for case only results: 0.0001
# Minimum cell count required for test: 5
# Total SNP pairs calculated: 4950
# Total SNP pair statistics passing threshold: 5
#
# Number of SNP pairs with results: 5
#
# Run time: 1 second

# %%
resultsJE<-read.table("cassiJE.out", header=T) 
resultsJE
# Out:
#   SNP1 CHR1 ID1   BP1      SNP2 CHR2 ID2    BP2       JE_CASE_LOG_OR JE_CASE_SE
# 1  1   0    snp1   1000000   2  0    snp2     2000000  2.929320      0.0827492
# 2  3   0    snp3   3000000   4  0    snp4     4000000  0.350718      0.0863819
# 3  4   0    snp4   4000000   5  0    snp5     5000000  0.371610      0.0851736
# 4 15   0    snp15 15000000  77  0    snp77   77000000 -0.202479      0.0739267
# 5 31   0    snp31 31000000 100  0    snp100 100000000  0.284926      0.0723418
#   JE_CTRL_LOG_OR JE_CTRL_SE JE_CC_CHISQ JE_CC_P      JE_CC_ALT JE_CO_CHISQ
# 1  0.00670512    0.0878829  586.21800   1.66520e-129 N         1253.16000
# 2  0.05162640    0.0916923    5.63702    1.75851e-02 N           16.48430
# 3 -0.07437630    0.0922595   12.61570    3.82518e-04 N           19.03550
# 4  0.23078500    0.0710405   17.85770    2.38057e-05 N            7.50168
# 5 -0.09335550    0.0714374   13.84370    1.98666e-04 N           15.51260
#   JE_CO_P      JE_CO_ALT
# 1 1.70712e-274 N
# 2  4.90549e-05 N
# 3  1.28308e-05 N
# 4  6.16414e-03 N
# 5  8.19557e-05 N
